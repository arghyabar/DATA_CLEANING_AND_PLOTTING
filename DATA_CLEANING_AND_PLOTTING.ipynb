# %%
import pandas as pd
US_pumpkins_df=pd.read_csv("US_pumpkins.csv")
US_pumpkins_df
# Out:
#       City Name Type        Package      Variety Sub Variety  Grade     Date  \
# 0     BALTIMORE  NaN   24 inch bins          NaN         NaN    NaN  4/29/17
# 1     BALTIMORE  NaN   24 inch bins          NaN         NaN    NaN   5/6/17
# 2     BALTIMORE  NaN   24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3     BALTIMORE  NaN   24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4     BALTIMORE  NaN   24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
# ...         ...  ...            ...          ...         ...    ...      ...
# 1752  ST. LOUIS  NaN  22 lb cartons    MINIATURE   FLAT TYPE    NaN  9/30/16
# 1753  ST. LOUIS  NaN   36 inch bins    MINIATURE  ROUND TYPE    NaN  9/26/16
# 1754  ST. LOUIS  NaN   36 inch bins    MINIATURE  ROUND TYPE    NaN  9/27/16
# 1755  ST. LOUIS  NaN   36 inch bins    MINIATURE  ROUND TYPE    NaN  9/28/16
# 1756  ST. LOUIS  NaN   36 inch bins    MINIATURE  ROUND TYPE    NaN  9/29/16
#
# ...

# %%
US_pumpkins_df.head()
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade     Date  \
# 0  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN  4/29/17
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN   5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/5/16
#
#    Low Price  High Price  Mostly Low  ...  Unit of Sale Quality Condition  \
# 0      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 1      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 2      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 3      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 4       90.0       100.0        90.0  ...           NaN     NaN       NaN
#
#   Appearance Storage  Crop Repack  Trans Mode  Unnamed: 24  Unnamed: 25
# ...

# %%
US_pumpkins_df.columns
# Out:
# Index(['City Name', 'Type', 'Package', 'Variety', 'Sub Variety', 'Grade',
#        'Date', 'Low Price', 'High Price', 'Mostly Low', 'Mostly High',
#        'Origin', 'Origin District', 'Item Size', 'Color', 'Environment',
#        'Unit of Sale', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop',
#        'Repack', 'Trans Mode', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
US_pumpkins_df.isnull()
# Out:
#       City Name  Type  Package  Variety  Sub Variety  Grade   Date  Low Price  \
# 0         False  True    False     True         True   True  False      False
# 1         False  True    False     True         True   True  False      False
# 2         False  True    False    False         True   True  False      False
# 3         False  True    False    False         True   True  False      False
# 4         False  True    False    False         True   True  False      False
# ...         ...   ...      ...      ...          ...    ...    ...        ...
# 1752      False  True    False    False        False   True  False      False
# 1753      False  True    False    False        False   True  False      False
# 1754      False  True    False    False        False   True  False      False
# 1755      False  True    False    False        False   True  False      False
# 1756      False  True    False    False        False   True  False      False
#
# ...

# %%
US_pumpkins_df.isnull().sum()
# Out:
# City Name             0
# Type               1712
# Package               0
# Variety               5
# Sub Variety        1461
# Grade              1757
# Date                  0
# Low Price             0
# High Price            0
# Mostly Low          103
# Mostly High         103
# Origin                3
# Origin District    1626
# Item Size           279
# Color               616
# Environment        1757
# Unit of Sale       1595
# Quality            1757
# Condition          1757
# Appearance         1757
# Storage            1757
# Crop               1757
# Repack                0
# Trans Mode         1757
# Unnamed: 24        1757
# Unnamed: 25        1654
# dtype: int64

# %%
US_pumpkins_df.fillna(0)
# Out:
#       City Name Type        Package      Variety Sub Variety  Grade     Date  \
# 0     BALTIMORE    0   24 inch bins            0           0    0.0  4/29/17
# 1     BALTIMORE    0   24 inch bins            0           0    0.0   5/6/17
# 2     BALTIMORE    0   24 inch bins  HOWDEN TYPE           0    0.0  9/24/16
# 3     BALTIMORE    0   24 inch bins  HOWDEN TYPE           0    0.0  9/24/16
# 4     BALTIMORE    0   24 inch bins  HOWDEN TYPE           0    0.0  11/5/16
# ...         ...  ...            ...          ...         ...    ...      ...
# 1752  ST. LOUIS    0  22 lb cartons    MINIATURE   FLAT TYPE    0.0  9/30/16
# 1753  ST. LOUIS    0   36 inch bins    MINIATURE  ROUND TYPE    0.0  9/26/16
# 1754  ST. LOUIS    0   36 inch bins    MINIATURE  ROUND TYPE    0.0  9/27/16
# 1755  ST. LOUIS    0   36 inch bins    MINIATURE  ROUND TYPE    0.0  9/28/16
# 1756  ST. LOUIS    0   36 inch bins    MINIATURE  ROUND TYPE    0.0  9/29/16
#
# ...

# %%
US_pumpkins_df['Low Price'].mean()
# Out:
# 124.57133750711428

# %%
US_pumpkins_df_drop=US_pumpkins_df.dropna()
US_pumpkins_df_drop.shape
# Out:
# (0, 26)

# %%
US_pumpkins_df_drop_column=US_pumpkins_df.dropna(axis=1)
US_pumpkins_df_drop_column.shape
# Out:
# (1757, 6)

# %%
x=US_pumpkins_df.loc[1:8]
x
# Out:
#    City Name Type       Package      Variety Sub Variety  Grade      Date  \
# 1  BALTIMORE  NaN  24 inch bins          NaN         NaN    NaN    5/6/17
# 2  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN   9/24/16
# 3  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN   9/24/16
# 4  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN   11/5/16
# 5  BALTIMORE  NaN  24 inch bins  HOWDEN TYPE         NaN    NaN  11/12/16
# 6  BALTIMORE  NaN  36 inch bins  HOWDEN TYPE         NaN    NaN   9/24/16
# 7  BALTIMORE  NaN  36 inch bins  HOWDEN TYPE         NaN    NaN   9/24/16
# 8  BALTIMORE  NaN  36 inch bins  HOWDEN TYPE         NaN    NaN   10/1/16
#
#    Low Price  High Price  Mostly Low  ...  Unit of Sale Quality Condition  \
# 1      270.0       280.0       270.0  ...           NaN     NaN       NaN
# 2      160.0       160.0       160.0  ...           NaN     NaN       NaN
# 3      160.0       160.0       160.0  ...           NaN     NaN       NaN
# ...

# %%
y=US_pumpkins_df.iloc[:8,7:11]
y
# Out:
#    Low Price  High Price  Mostly Low  Mostly High
# 0      270.0       280.0       270.0        280.0
# 1      270.0       280.0       270.0        280.0
# 2      160.0       160.0       160.0        160.0
# 3      160.0       160.0       160.0        160.0
# 4       90.0       100.0        90.0        100.0
# 5       90.0       100.0        90.0        100.0
# 6      160.0       170.0       160.0        170.0
# 7      160.0       160.0       160.0        160.0

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
a=sns.countplot(x['Mostly High'])
print(type(a))
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# C:\Users\arghy\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(data=US_pumpkins_df['Sub Variety'], kde=True)

# %%
list(set(US_pumpkins_df.dtypes.tolist()))
df_num = US_pumpkins_df.select_dtypes(include = ['float64', 'int64'])
df_num
df_num.dropna(axis=1,how='any')
# Out:
#       Low Price  High Price
# 0        270.00      280.00
# 1        270.00      280.00
# 2        160.00      160.00
# 3        160.00      160.00
# 4         90.00      100.00
# ...         ...         ...
# 1752      14.75       14.75
# 1753     275.00      275.00
# 1754     275.00      275.00
# 1755     275.00      275.00
# 1756     275.00      275.00
#
# [1757 rows x 2 columns]

# %%
num_df=US_pumpkins_df[['High Price','Low Price']]
num_df.hist(figsize=(20,8),
            bins=10, 
            xlabelsize=8,
            ylabelsize=8);

# %%
plot_df = y[~y.index.duplicated(keep='Low Price')]
sns.pairplot(y, diag_kind='High Price')

# %%
plt.subplots(figsize = (20,5))
plt.title('Low_price_city_name ')
sns.boxplot(x = "City Name", y = "Low Price",data = US_pumpkins_df)
# Out:
# <AxesSubplot:title={'center':'Low_price_city_name '}, xlabel='City Name', ylabel='Low Price'>

# %%
plt.subplots(figsize = (20,5))
plt.title('High_price_city_name ')
sns.boxplot(x = "City Name", y = "High Price",data = US_pumpkins_df)
# Out:
# <AxesSubplot:title={'center':'High_price_city_name '}, xlabel='City Name', ylabel='High Price'>

# %%
sns.heatmap(x.corr(),annot=True, fmt='.2f', cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x = "Unnamed: 24", y = "Unnamed: 25", 
            data = US_pumpkins_df,
            marker=">" , 
            color="b",
            x_estimator=x.mean, 
            logx=True
           )
plt.show()
